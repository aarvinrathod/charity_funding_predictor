# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
# Reading .csv into dataframe
df = pd.read_csv("charity_data.csv")

# %%
# Drop no-use columns
df2 = df.drop(columns = ["EIN", "NAME"])

# %%
# Check Number of Unique Values in each column
df2.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Binnig asking amount and creating a new column
bins = [0, 5000, 10000, 50000, 100000, 500000, 1000000, 2000000, 5000000, 10000000, 100000000, 1000000000, 10000000000]
labels = ["5k", "5k-10k", "10k-50k", "50k-100k", "100k-500k", "500k-1M", "1M-2M", "2M-5M", "5M-10M", "10M-100M", "100M-1T", "1T+"]
df2["asking_amount_binned"] = pd.cut(df2["ASK_AMT"], bins=bins, labels=labels)
df2["asking_amount_binned"].value_counts()
# Out:
# 5k           25398
# 10k-50k       2398
# 100k-500k     2304
# 50k-100k      1423
# 500k-1M        650
# 5k-10k         549
# 1M-2M          485
# 2M-5M          455
# 10M-100M       311
# 5M-10M         225
# 100M-1T         83
# 1T+             18
# Name: asking_amount_binned, dtype: int64

# %%
# Grouping classification values with less than 50 instances as "Other"
df3 = df2["CLASSIFICATION"].value_counts()
df3 = df3.reset_index()
df3 = df3[df3.CLASSIFICATION < 50]
form_names = df3["index"]
form_names = list(form_names)
df4 = df2.replace(form_names, "Other")
df4["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      391
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# Name: CLASSIFICATION, dtype: int64

# %%
# Grouping Application Type with less than 100 instances as other
df5 = df2["APPLICATION_TYPE"].value_counts()
df5 = df5.reset_index()
df5 = df5[df5.APPLICATION_TYPE < 100]
app_names = df5["index"]
app_names = list(app_names)
df6 = df4.replace(app_names, "Other")
df6["APPLICATION_TYPE"].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Dropping columns of no use and verifying number of unique values for all columns in dataframe
df6 = df6.drop(columns=["ASK_AMT", "STATUS", "SPECIAL_CONSIDERATIONS"])
df6.nunique()
# Out:
# APPLICATION_TYPE        10
# AFFILIATION              6
# CLASSIFICATION          16
# USE_CASE                 5
# ORGANIZATION             4
# INCOME_AMT               9
# IS_SUCCESSFUL            2
# asking_amount_binned    12
# dtype: int64

# %%
df6 = pd.get_dummies(df6)

# %%
df6
# Out:
#        IS_SUCCESSFUL  ...  asking_amount_binned_1T+
# 0                  1  ...                         0
# 1                  1  ...                         0
# 2                  0  ...                         0
# 3                  1  ...                         0
# 4                  1  ...                         0
# ...              ...  ...                       ...
# 34294              0  ...                         0
# 34295              0  ...                         0
# 34296              0  ...                         0
# 34297              1  ...                         0
# 34298              0  ...                         0
#
# [34299 rows x 63 columns]

# %%
X = df6.drop(columns=["IS_SUCCESSFUL"])
y = df6["IS_SUCCESSFUL"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Defining the deep learning model with one hidden layer

nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=62))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5947 - accuracy: 0.7031
# Epoch 2/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5631 - accuracy: 0.7261
# Epoch 3/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5574 - accuracy: 0.7287
# Epoch 4/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5544 - accuracy: 0.7292
# Epoch 5/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5532 - accuracy: 0.7301
# Epoch 6/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5514 - accuracy: 0.7312
# Epoch 7/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5505 - accuracy: 0.7301
# Epoch 8/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5503 - accuracy: 0.7319
# Epoch 9/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5490 - accuracy: 0.7311
# Epoch 10/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5481 - accuracy: 0.7315
# Epoch 11/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7315
# Epoch 12/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5474 - accuracy: 0.7317
# Epoch 13/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5470 - accuracy: 0.7314
# Epoch 14/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5465 - accuracy: 0.7330
# Epoch 15/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5463 - accuracy: 0.7322
# Epoch 16/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5457 - accuracy: 0.7328
# Epoch 17/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5453 - accuracy: 0.7329
# Epoch 18/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5452 - accuracy: 0.7329
# Epoch 19/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5451 - accuracy: 0.7332
# Epoch 20/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5446 - accuracy: 0.7339
# Epoch 21/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5445 - accuracy: 0.7334
# Epoch 22/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5440 - accuracy: 0.7328
# Epoch 23/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7331
# Epoch 24/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.7339
# Epoch 25/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.7334
# Epoch 26/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5434 - accuracy: 0.7352
# Epoch 27/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7352
# Epoch 28/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7352
# Epoch 29/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7336
# Epoch 30/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7350
# Epoch 31/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7348
# Epoch 32/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7349
# Epoch 33/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.7351
# Epoch 34/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5417 - accuracy: 0.7351
# Epoch 35/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.7356
# Epoch 36/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7353
# Epoch 37/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7365
# Epoch 38/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5415 - accuracy: 0.7343
# Epoch 39/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5408 - accuracy: 0.7351
# Epoch 40/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7357
# Epoch 41/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5405 - accuracy: 0.7350
# Epoch 42/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7371
# Epoch 43/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7346
# Epoch 44/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7363
# Epoch 45/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5401 - accuracy: 0.7359
# Epoch 46/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5404 - accuracy: 0.7357
# Epoch 47/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.7367
# Epoch 48/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7358
# Epoch 49/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7353
# Epoch 50/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7359
# 268/268 - 0s - loss: 0.5427 - accuracy: 0.7306
# Loss: 0.542741060256958, Accuracy: 0.7306122183799744

# %%
# Defining the deep learning model with one hidden layer

nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim=62))
nn_model.add(tf.keras.layers.Dense(units=20, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=75)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5878 - accuracy: 0.7048
# Epoch 2/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5562 - accuracy: 0.7290
# Epoch 3/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5519 - accuracy: 0.7297
# Epoch 4/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5493 - accuracy: 0.7324
# Epoch 5/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5476 - accuracy: 0.7312
# Epoch 6/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7313
# Epoch 7/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5455 - accuracy: 0.7326
# Epoch 8/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5446 - accuracy: 0.7320
# Epoch 9/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5440 - accuracy: 0.7322
# Epoch 10/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5429 - accuracy: 0.7342
# Epoch 11/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7348
# Epoch 12/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7354
# Epoch 13/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7345
# Epoch 14/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5410 - accuracy: 0.7364
# Epoch 15/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5401 - accuracy: 0.7361
# Epoch 16/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7371
# Epoch 17/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5393 - accuracy: 0.7369
# Epoch 18/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5394 - accuracy: 0.7367
# Epoch 19/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5387 - accuracy: 0.7377
# Epoch 20/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5383 - accuracy: 0.7388
# Epoch 21/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7378
# Epoch 22/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5380 - accuracy: 0.7365
# Epoch 23/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7378
# Epoch 24/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5370 - accuracy: 0.7377
# Epoch 25/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7386
# Epoch 26/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7383
# Epoch 27/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7385
# Epoch 28/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5360 - accuracy: 0.7392
# Epoch 29/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7395
# Epoch 30/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7394
# Epoch 31/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7407
# Epoch 32/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5349 - accuracy: 0.7395
# Epoch 33/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5350 - accuracy: 0.7407
# Epoch 34/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5344 - accuracy: 0.7405
# Epoch 35/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7402
# Epoch 36/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7413
# Epoch 37/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7416
# Epoch 38/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7404
# Epoch 39/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7409
# Epoch 40/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5333 - accuracy: 0.7405
# Epoch 41/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7411
# Epoch 42/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7408
# Epoch 43/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7423
# Epoch 44/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7414
# Epoch 45/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7407
# Epoch 46/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7413
# Epoch 47/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7410
# Epoch 48/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7426
# Epoch 49/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5317 - accuracy: 0.7423
# Epoch 50/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5318 - accuracy: 0.7404
# Epoch 51/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5319 - accuracy: 0.7425
# Epoch 52/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5316 - accuracy: 0.7421
# Epoch 53/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5312 - accuracy: 0.7425
# Epoch 54/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5311 - accuracy: 0.7427
# Epoch 55/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5314 - accuracy: 0.7426
# Epoch 56/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5305 - accuracy: 0.7424
# Epoch 57/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5311 - accuracy: 0.7423
# Epoch 58/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5308 - accuracy: 0.7434
# Epoch 59/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5306 - accuracy: 0.7423
# Epoch 60/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5304 - accuracy: 0.7431
# Epoch 61/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5307 - accuracy: 0.7432
# Epoch 62/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5301 - accuracy: 0.7431
# Epoch 63/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5304 - accuracy: 0.7418
# Epoch 64/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5301 - accuracy: 0.7434
# Epoch 65/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5301 - accuracy: 0.7432
# Epoch 66/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5297 - accuracy: 0.7434
# Epoch 67/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5296 - accuracy: 0.7432
# Epoch 68/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5293 - accuracy: 0.7427
# Epoch 69/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5291 - accuracy: 0.7432
# Epoch 70/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5295 - accuracy: 0.7437
# Epoch 71/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5290 - accuracy: 0.7434
# Epoch 72/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5291 - accuracy: 0.7437
# Epoch 73/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5291 - accuracy: 0.7441
# Epoch 74/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5292 - accuracy: 0.7441
# Epoch 75/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5290 - accuracy: 0.7431
# 268/268 - 0s - loss: 0.5498 - accuracy: 0.7286
# Loss: 0.5498145222663879, Accuracy: 0.7286297082901001
