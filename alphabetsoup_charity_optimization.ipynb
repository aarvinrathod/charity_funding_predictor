# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %%
# Reading .csv into dataframe
df = pd.read_csv("charity_data.csv")

# %%
# Drop no-use columns
df2 = df.drop(columns = ["EIN", "NAME"])

# %%
# Check Number of Unique Values in each column
df2.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Binnig asking amount and creating a new column
bins = [0, 5000, 10000, 50000, 100000, 500000, 1000000, 2000000, 5000000, 10000000, 100000000, 1000000000, 10000000000]
labels = ["5k", "5k-10k", "10k-50k", "50k-100k", "100k-500k", "500k-1M", "1M-2M", "2M-5M", "5M-10M", "10M-100M", "100M-1T", "1T+"]
df2["asking_amount_binned"] = pd.cut(df2["ASK_AMT"], bins=bins, labels=labels)
df2["asking_amount_binned"].value_counts()
# Out:
# 5k           25398
# 10k-50k       2398
# 100k-500k     2304
# 50k-100k      1423
# 500k-1M        650
# 5k-10k         549
# 1M-2M          485
# 2M-5M          455
# 10M-100M       311
# 5M-10M         225
# 100M-1T         83
# 1T+             18
# Name: asking_amount_binned, dtype: int64

# %%
# Grouping classification values with less than 50 instances as "Other"
df3 = df2["CLASSIFICATION"].value_counts()
df3 = df3.reset_index()
df3 = df3[df3.CLASSIFICATION < 50]
form_names = df3["index"]
form_names = list(form_names)
df4 = df2.replace(form_names, "Other")
df4["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      391
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# Name: CLASSIFICATION, dtype: int64

# %%
# Grouping Application Type with less than 100 instances as other
df5 = df2["APPLICATION_TYPE"].value_counts()
df5 = df5.reset_index()
df5 = df5[df5.APPLICATION_TYPE < 100]
app_names = df5["index"]
app_names = list(app_names)
df6 = df4.replace(app_names, "Other")
df6["APPLICATION_TYPE"].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Dropping columns of no use and verifying number of unique values for all columns in dataframe
df6 = df6.drop(columns=["ASK_AMT", "STATUS", "SPECIAL_CONSIDERATIONS"])
df6.nunique()
# Out:
# APPLICATION_TYPE        10
# AFFILIATION              6
# CLASSIFICATION          16
# USE_CASE                 5
# ORGANIZATION             4
# INCOME_AMT               9
# IS_SUCCESSFUL            2
# asking_amount_binned    12
# dtype: int64

# %%
df6 = pd.get_dummies(df6)

# %%
df6
# Out:
#        IS_SUCCESSFUL  ...  asking_amount_binned_1T+
# 0                  1  ...                         0
# 1                  1  ...                         0
# 2                  0  ...                         0
# 3                  1  ...                         0
# 4                  1  ...                         0
# ...              ...  ...                       ...
# 34294              0  ...                         0
# 34295              0  ...                         0
# 34296              0  ...                         0
# 34297              1  ...                         0
# 34298              0  ...                         0
#
# [34299 rows x 63 columns]

# %%
X = df6.drop(columns=["IS_SUCCESSFUL"])
y = df6["IS_SUCCESSFUL"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Defining the deep learning model with one hidden layer

nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=62))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5994 - accuracy: 0.7072
# Epoch 2/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5628 - accuracy: 0.7240
# Epoch 3/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5562 - accuracy: 0.7287
# Epoch 4/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5536 - accuracy: 0.7293
# Epoch 5/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5514 - accuracy: 0.7295
# Epoch 6/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5506 - accuracy: 0.7304
# Epoch 7/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7304
# Epoch 8/50
# 513/804 [==================>...........] - ETA: 0s - loss: 0.5455 - accuracy: 0.7325
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-ca1c1172c191> in <module>()
#       9
#      10 # Train the model
# ---> 11 fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
#      12
#      13 # Evaluate the model using the test data
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1187               logs = tmp_logs  # No error, now safe to assign to logs.
#    1188               end_step = step + data_handler.step_increment
# -> 1189               callbacks.on_train_batch_end(end_step, logs)
#    1190               if self.stop_training:
#    1191                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     433     """
#     434     if self._should_call_train_batch_hooks:
# --> 435       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     436
#     437   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     313       self._batch_times.append(batch_time)
#     314
# --> 315     self._call_batch_hook_helper(hook_name, batch, logs)
#     316
#     317     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     351     for callback in self.callbacks:
#     352       hook = getattr(callback, hook_name)
# --> 353       hook(batch, logs)
#     354
#     355     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1026
#    1027   def on_train_batch_end(self, batch, logs=None):
# -> 1028     self._batch_update_progbar(batch, logs)
#    1029
#    1030   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1098     if self.verbose == 1:
#    1099       # Only block async when verbose = 1.
# -> 1100       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1101       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1102
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#     515
# --> 516   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     517
#     518
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     509
#     510   def _to_single_numpy_or_python_type(t):
# --> 511     if isinstance(t, tf.Tensor):
#     512       x = t.numpy()
#     513       return x.item() if np.ndim(x) == 0 else x
#
# KeyboardInterrupt:

# %%
# Define the model - deep neural net
hidden_nodes_layer1 =  20
hidden_nodes_layer2 = 20


nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim=62))
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5858 - accuracy: 0.7135
# Epoch 2/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5557 - accuracy: 0.7304
# Epoch 3/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7311
# Epoch 4/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5469 - accuracy: 0.7326
# Epoch 5/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5452 - accuracy: 0.7323
# Epoch 6/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7339
# Epoch 7/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7355
# Epoch 8/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.7355
# Epoch 9/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5405 - accuracy: 0.7365
# Epoch 10/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7360
# Epoch 11/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5398 - accuracy: 0.7372
# Epoch 12/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7381
# Epoch 13/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7379
# Epoch 14/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7378
# Epoch 15/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7380
# Epoch 16/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7380
# Epoch 17/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7378
# Epoch 18/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7392
# Epoch 19/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7378
# Epoch 20/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7385
# Epoch 21/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7386
# Epoch 22/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7400
# Epoch 23/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7394
# Epoch 24/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7393
# Epoch 25/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7392
# Epoch 26/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7409
# Epoch 27/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5334 - accuracy: 0.7409
# Epoch 28/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7406
# Epoch 29/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7403
# Epoch 30/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7406
# Epoch 31/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7409
# Epoch 32/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7413
# Epoch 33/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7412
# Epoch 34/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7405
# Epoch 35/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7419
# Epoch 36/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7400
# Epoch 37/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7418
# Epoch 38/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5306 - accuracy: 0.7414
# Epoch 39/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.7405
# Epoch 40/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5306 - accuracy: 0.7410
# Epoch 41/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.7424
# Epoch 42/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5299 - accuracy: 0.7421
# Epoch 43/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5293 - accuracy: 0.7422
# Epoch 44/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5294 - accuracy: 0.7426
# Epoch 45/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5291 - accuracy: 0.7434
# Epoch 46/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5294 - accuracy: 0.7423
# Epoch 47/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5288 - accuracy: 0.7424
# Epoch 48/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5296 - accuracy: 0.7421
# Epoch 49/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5286 - accuracy: 0.7428
# Epoch 50/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5288 - accuracy: 0.7425
# 268/268 - 0s - loss: 0.5608 - accuracy: 0.7259
# Loss: 0.5608155131340027, Accuracy: 0.7259474992752075

# %%
# Defining the deep learning model with one hidden layer

nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=100, activation="relu", input_dim=62))
nn_model.add(tf.keras.layers.Dense(units=30, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5704 - accuracy: 0.7207
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5500 - accuracy: 0.7324
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5461 - accuracy: 0.7336
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7344
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7365
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7362
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7364
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7385
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7391
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7402
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7399
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7402
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7406
# Epoch 14/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7416
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7402
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5303 - accuracy: 0.7434
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.7427
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5300 - accuracy: 0.7434
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5292 - accuracy: 0.7424
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5288 - accuracy: 0.7434
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5285 - accuracy: 0.7426
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7440
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7438
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7439
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5260 - accuracy: 0.7454
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5257 - accuracy: 0.7451
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5253 - accuracy: 0.7462
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5254 - accuracy: 0.7457
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5245 - accuracy: 0.7445
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5243 - accuracy: 0.7456
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5238 - accuracy: 0.7476
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5227 - accuracy: 0.7465
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5229 - accuracy: 0.7464
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5226 - accuracy: 0.7474
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5225 - accuracy: 0.7468
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5217 - accuracy: 0.7480
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5221 - accuracy: 0.7481
# Epoch 38/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5221 - accuracy: 0.7481
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5214 - accuracy: 0.7475
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5209 - accuracy: 0.7478
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5205 - accuracy: 0.7483
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5203 - accuracy: 0.7479
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5200 - accuracy: 0.7486
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5198 - accuracy: 0.7487
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5202 - accuracy: 0.7476
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5196 - accuracy: 0.7486
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5193 - accuracy: 0.7493
# Epoch 48/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5185 - accuracy: 0.7493
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5195 - accuracy: 0.7481
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5186 - accuracy: 0.7499
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5184 - accuracy: 0.7493
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5179 - accuracy: 0.7493
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5177 - accuracy: 0.7492
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5177 - accuracy: 0.7498
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5178 - accuracy: 0.7493
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5175 - accuracy: 0.7490
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5176 - accuracy: 0.7502
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5165 - accuracy: 0.7491
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5172 - accuracy: 0.7500
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5166 - accuracy: 0.7491
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5166 - accuracy: 0.7502
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5166 - accuracy: 0.7490
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5163 - accuracy: 0.7505
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5162 - accuracy: 0.7496
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5159 - accuracy: 0.7507
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5158 - accuracy: 0.7504
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5157 - accuracy: 0.7497
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5159 - accuracy: 0.7500
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5155 - accuracy: 0.7502
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5154 - accuracy: 0.7500
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5153 - accuracy: 0.7498
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5146 - accuracy: 0.7505
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5153 - accuracy: 0.7511
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5144 - accuracy: 0.7505
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5145 - accuracy: 0.7510
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5142 - accuracy: 0.7509
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5145 - accuracy: 0.7514
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5146 - accuracy: 0.7500
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5146 - accuracy: 0.7498
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5141 - accuracy: 0.7504
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5144 - accuracy: 0.7493
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5133 - accuracy: 0.7510
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5141 - accuracy: 0.7503
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5141 - accuracy: 0.7505
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5137 - accuracy: 0.7497
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5135 - accuracy: 0.7508
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5137 - accuracy: 0.7507
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5136 - accuracy: 0.7508
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5136 - accuracy: 0.7507
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5131 - accuracy: 0.7505
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5132 - accuracy: 0.7507
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5131 - accuracy: 0.7507
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5128 - accuracy: 0.7504
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5127 - accuracy: 0.7514
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5130 - accuracy: 0.7502
# Epoch 96/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5127 - accuracy: 0.7504
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5126 - accuracy: 0.7520
# Epoch 98/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5128 - accuracy: 0.7504
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5122 - accuracy: 0.7516
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5124 - accuracy: 0.7505
# 268/268 - 0s - loss: 0.5853 - accuracy: 0.7226
# Loss: 0.5853332877159119, Accuracy: 0.7225655913352966

# %%
# Drop no-use columns
df8 = df.drop(columns = ["EIN", "NAME"])
# Binnig asking amount and creating a new column
bins = [0, 5000, 100000, 500000, 10000000000]
labels = ["5k", "5k-100k", "100k-500k", "500k+"]
df8["asking_amount_binned"] = pd.cut(df8["ASK_AMT"], bins=bins, labels=labels)
df8["asking_amount_binned"].value_counts()
# Out:
# 5k           25398
# 5k-100k       4370
# 100k-500k     2304
# 500k+         2227
# Name: asking_amount_binned, dtype: int64

# %%
# Grouping classification values with less than 500 instances as "Other"
df9 = df2["CLASSIFICATION"].value_counts()
df9 = df9.reset_index()
df9 = df9[df9.CLASSIFICATION < 500]
form_names = df9["index"]
form_names = list(form_names)
df8 = df8.replace(form_names, "Other")
df8["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Grouping Application Type with less than 1000 instances as other
df5 = df2["APPLICATION_TYPE"].value_counts()
df5 = df5.reset_index()
df5 = df5[df5.APPLICATION_TYPE < 1000]
app_names = df5["index"]
app_names = list(app_names)
df8 = df8.replace(app_names, "Other")
df8["APPLICATION_TYPE"].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
df8 = df8.drop(columns=["ASK_AMT", "STATUS", "SPECIAL_CONSIDERATIONS"])
df8 = pd.get_dummies(df8)
df8.head()
# Out:
#    IS_SUCCESSFUL  ...  asking_amount_binned_500k+
# 0              1  ...                           0
# 1              1  ...                           0
# 2              0  ...                           0
# 3              1  ...                           0
# 4              1  ...                           0
#
# [5 rows x 42 columns]

# %%
X = df8.drop(columns=["IS_SUCCESSFUL"])
y = df8["IS_SUCCESSFUL"]

X_train, X_test, y_train, y_test = train_test_split(X, y)

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Defining the deep learning model with one hidden layer

nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=100, activation="relu", input_dim=41))
nn_model.add(tf.keras.layers.Dense(units=30, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5728 - accuracy: 0.7169
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5582 - accuracy: 0.7257
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5553 - accuracy: 0.7272
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5539 - accuracy: 0.7289
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5525 - accuracy: 0.7294
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5509 - accuracy: 0.7298
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5504 - accuracy: 0.7307
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5496 - accuracy: 0.7314
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5487 - accuracy: 0.7308
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5482 - accuracy: 0.7318
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5473 - accuracy: 0.7325
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7316
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5466 - accuracy: 0.7329
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5463 - accuracy: 0.7325
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5457 - accuracy: 0.7336
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5452 - accuracy: 0.7341
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5445 - accuracy: 0.7343
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5444 - accuracy: 0.7344
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5442 - accuracy: 0.7341
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5438 - accuracy: 0.7342
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5436 - accuracy: 0.7348
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7348
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7351
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7350
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7360
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5418 - accuracy: 0.7362
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7361
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5416 - accuracy: 0.7358
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7332
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7369
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7362
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7367
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7370
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5398 - accuracy: 0.7371
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7370
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7376
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5396 - accuracy: 0.7374
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7366
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5389 - accuracy: 0.7371
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7370
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7381
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7379
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5381 - accuracy: 0.7371
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5385 - accuracy: 0.7374
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7378
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7390
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7385
# Epoch 48/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7386
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7383
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7382
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7389
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7374
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5360 - accuracy: 0.7385
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7386
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7391
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7388
# Epoch 57/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7393
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7392
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7390
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7382
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7379
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7389
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5356 - accuracy: 0.7401
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7390
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7394
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7397
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7390
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7390
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7391
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7396
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7383
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5344 - accuracy: 0.7390
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7393
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7390
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7399
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7397
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7395
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7399
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7391
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7395
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7403
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7397
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7398
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7394
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7392
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7389
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7404
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7393
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7396
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7398
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7399
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5327 - accuracy: 0.7396
# Epoch 93/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7398
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7397
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7405
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7392
# Epoch 97/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7399
# Epoch 98/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7399
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7395
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7394
# 268/268 - 0s - loss: 0.5636 - accuracy: 0.7331
# Loss: 0.5635778307914734, Accuracy: 0.7330612540245056

# %%
# !mkdir -p saved_model
nn_model.save('content/sample_data/AlphabetSoupCharity_Optimization.h5')

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=100, random_state=0)
clf.fit(X_train_scaled, y_train)
clf.score(X_test_scaled, y_test)
# Out:
# 0.7322448979591837
